# %% [markdown]
# # An analysis of paleo-present climate data

# %% [markdown]
# ## Table of Contents
#
# 1. [Introduction](#Introduction)
# 2. [Analyse CO2 vs Temperature Anomaly from 800kyrs – present](#Analyse-CO2-vs-Temperature-Anomaly)
# 3. [Additional Analyses](#Additional-Analyses)
#    - [Methane (CH4)](#Methane-(CH4))
#    - [The Irish Context](#Irish-Context)
# 4. [Data Fusion and Analysis](#Data-Fusion)
# 5. [Future Predictions and Comparisons](#Future-Predictions)
# 6. [Accelerated Warming and Climate Impacts](#Accelerated-Warming)
#
# ---
#
# <a id='Introduction'></a>
# ## 1. Introduction
#
# Climate change, marked by alterations in global climate patterns, is predominantly driven by the increase in greenhouse gases such as carbon dioxide (CO2) and methane (CH4). The greenhouse effect, enhanced by these gases, leads to global warming and various climatic shifts.
#
# CO2, a primary greenhouse gas, has seen a significant rise due to human activities like fossil fuel combustion and deforestation. Since the industrial revolution, the levels of CO2 have increased from about 280 ppm to over 410 ppm. This rise in CO2 levels has shown a strong correlation with the global temperature anomaly, a deviation from a baseline or average temperature, indicating an upward trend in global warming.
#
# Methane, though less abundant, is highly effective at trapping heat in the atmosphere, contributing notably to climate change. Its sources include both natural processes and human activities.
#
# In Ireland, studies, such as those from Maynooth University, have started showing clear signals of climate change in long-term meteorological observations, indicating a pattern consistent with global trends.
#
# This study aims to analyze the relationship between CO2 levels and temperature anomalies from the past 800,000 years to the present, examining additional variables like CH4 and polar ice coverage. It will involve fusing data from various sources, analyzing trends, relationships, and temporal dynamics, and predicting future scenarios based on current trends.
#
# ---

# %% [markdown]
# <a id='Analyse-CO2-vs-Temperature-Anomaly'></a>
# ## 2. Analyse CO2 vs Temperature Anomaly from 800kyrs – present
#
# In this section, we analyze the relationship between atmospheric CO2 concentrations and temperature anomalies over a significant timespan, from 800,000 years ago to the present. This analysis involves synthesizing data from two key datasets: CO2 levels and global temperature anomalies.

# %%
# Start with loading in our Co2 Data

import pandas as pd

# CO2 Data import 'grl52461-sup-0003-supplementary file on Moodle'
# Note: data source file was manually altered due to difficulties creating a dataframe whereby data matched full-data set [tab 3 CO2 Composite].

# DataFrame for Co2 data from 800k years ago
url = "https://raw.githubusercontent.com/nf-me/project2/master/data_files/co2_data/old_data.csv"
df_co2_1 = pd.read_csv(url)

# Rename columns
df_co2_1 = df_co2_1.rename(columns={'date': 'period', 
                        'Research': 'research_project', 
                        'gasage_yr_bp': 'gasage_yr_bp', 
                        'co2_ppmv': 'Co2', 
                        'sig_mean_co2_ppmv': 'sig_mean_co2_ppmv'})

# Adjusted Year Calculation
def calculate_adjusted_year(gas_age):
    if gas_age <= 0:
        # Years AD (Anno Domini): Positive, counting from year 0
        return int(1950 - gas_age)
    else:
        # Years BC (Before Christ): Negative, counting down to year 0
        return int(gas_age - 1950) * -1

# Making our own Year Column
df_co2_1['Year'] = df_co2_1['gasage_yr_bp'].apply(calculate_adjusted_year)
df_co2_1.drop(columns=['period', 'research_project','gasage_yr_bp','sig_mean_co2_ppmv'], inplace=True)

# Keep DataFrame simple and consistent order with Year and variable and round to 2 decimal places for readability
new_column_order = ['Year', 'Co2']
df_co2_1 = df_co2_1.reindex(columns=new_column_order)
df_co2_1['Co2'] = df_co2_1['Co2'].round(2)

# %%
# Calculating Descriptive Statistics
co2_desc1 = df_co2_1.describe()
co2_desc1.round(2)
# Out:
#             Year      Co2
# count    1901.00  1901.00
# mean  -240859.90   235.57
# std    274261.07    35.90
# min   -803718.00   173.71
# 25%   -502227.00   204.83
# 50%    -72575.00   232.46
# 75%    -12656.00   257.93
# max      2001.00   368.02

# %% [markdown]
# ### Descriptive Statistics of CO2 Data (800k BC to 2001 AD)
#
# The CO2 dataset, comprising 1901 observations, spans a timeline from 803,718 BC to 2001 AD. The average CO2 concentration over this period is approximately 235.57 ppmv, with a standard deviation of 35.90 ppmv, indicating variability in CO2 levels. The minimum recorded CO2 concentration is 173.71 ppmv, while the maximum is 368.02 ppmv. Notably, the 25th percentile (204.83 ppmv) and the 75th percentile (257.93 ppmv) highlight the range of CO2 concentrations through different historical periods.

# %%
import pandas as pd

# import CO2 values taken Mauna Loa fro, 1959 to 2024
# URL of the data file
url = 'https://gml.noaa.gov/webdata/ccgg/trends/co2/co2_annmean_mlo.txt'

# Define column names
column_names = ['Year', 'Co2', 'unc']

# Import the data into a DataFrame
df_co2_2 = pd.read_csv(url, sep='\s+', comment='#', names=column_names, header=None, engine='python', skiprows=29)
df_co2_2.drop(columns=['unc'], inplace=True)
df_co2_2['Co2'] = df_co2_2['Co2'].round(2)

# %%
# Calculating Descriptive Statistics
co2_desc2 = df_co2_2.describe()
co2_desc2.round(2)
# Out:
#           Year     Co2
# count    65.00   65.00
# mean   1991.00  359.26
# std      18.91   31.32
# min    1959.00  315.98
# 25%    1975.00  331.13
# 50%    1991.00  355.70
# 75%    2007.00  384.02
# max    2023.00  421.08

# %% [markdown]
# ### Descriptive Statistics of Recent CO2 Data (Mauna Loa, 1959-2024)
#
# The CO2 dataset from Mauna Loa Observatory, covering the period from 1959 to 2024, includes 65 annual mean CO2 measurements. The average CO2 concentration for this period is approximately 359.26 ppmv, reflecting the recent rise in CO2 levels. The standard deviation of 31.32 ppmv indicates significant variability over these years. The minimum CO2 level recorded in this dataset is 315.98 ppmv (in 1959), and the maximum is 421.00 ppmv (in 2023), showcasing a clear upward trend in atmospheric CO2 concentrations in recent decades.

# %%
# Look at overlapping time periods and take an average
# overly complicated something there may have been an easier solution too and can be re-done in future

combined1_df = pd.merge(df_co2_1, df_co2_2, how='inner', left_on='Year', right_on='Year')

combined1_df = pd.merge(df_co2_1[df_co2_1['Year'].between(1959, 2001)], 
                     df_co2_2[df_co2_2['Year'].between(1959, 2001)], 
                     left_on='Year', right_on='Year')

combined1_df['Co2'] = combined1_df[['Co2_x', 'Co2_y']].mean(axis=1)
combined1_df.drop(columns=['Co2_x', 'Co2_y'], inplace=True)

# Now we have taken average of all those years that match for Co2 and created a df for them
# Nex we need to make the non-overlapping df and combine all of this data backtogether

# Non-overlapping data
combined2_df = df_co2_1[~df_co2_1['Year'].between(1959, 2001)]
combined3_df = df_co2_2[~df_co2_2['Year'].between(1959, 2001)]

# Combine all data back together
co2_df = pd.concat([combined1_df, combined2_df, combined3_df]).sort_values(by='Year')
co2_df['Co2'] = co2_df['Co2'].round(2)

# Create new column called co2_deviation (Co2 - mean)
co2_mean = co2_df['Co2'].mean()
co2_df['co2_dev'] = co2_df['Co2'] - co2_mean
co2_df['co2_dev'] = co2_df['co2_dev'].round(2)

# %%
# Calculating Descriptive Statistics
co2_desc_df = co2_df.describe()
co2_desc_df.round(2)
# Out:
#             Year      Co2  co2_dev
# count    1923.00  1923.00  1923.00
# mean  -238081.33   237.42     0.00
# std    273908.03    39.66    39.66
# min   -803718.00   173.71   -63.71
# 25%   -497965.00   205.14   -32.28
# 50%    -68102.00   233.00    -4.42
# 75%    -12375.50   259.55    22.13
# max      2023.00   421.08   183.66

# %%
# Show Co2 over Years
import matplotlib.pyplot as plt

plt.style.use('seaborn-darkgrid')
plt.figure(figsize=(14, 7))
plt.plot(co2_df['Year'], co2_df['Co2'], marker='o', linestyle='-', linewidth=2, color='seagreen', markersize=5)
plt.title('CO2 Concentration Over Years', fontsize=18)
plt.xlabel('Year', fontsize=14)
plt.ylabel('CO2 Concentration (ppmv)', fontsize=14)
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Visualization of CO2 Concentration Over the Years
#
# The plot above illustrates the trend in atmospheric CO2 concentrations spanning from the earliest recorded data to the present day. The following observations can be made from this visualization:
#
# - **Increasing Trend**: The line plot distinctly shows an upward trajectory in CO2 levels over time. This increase becomes more pronounced in recent decades, highlighting the significant impact of industrialization and increased fossil fuel usage.
#
# - **Yearly Variability**: These fluctuations are a normal part of the atmospheric CO2 cycle, influenced by seasonal changes in vegetation and ocean-atmosphere interactions.
#
# - **Historical Context**: The early portion of the plot, representing data from hundreds of thousands of years ago, provides a baseline for natural CO2 levels before significant human impact. In contrast, the data from recent years, particularly from Mauna Loa Observatory, show a marked deviation from these historical levels.
#
# This plot serves as a stark reminder of the ongoing challenges posed by increasing greenhouse gas emissions and underscores the urgency of addressing climate change.

# %%
# Temperature Data

import pandas as pd

# URLs of the datasets
url1 = "https://raw.githubusercontent.com/nf-me/project2/master/data_files/temp_data/edc3deuttemp2007.csv"
url2 = "https://raw.githubusercontent.com/nf-me/project2/master/data_files/temp_data/nasa_globaltemp.csv"

# Reading the data into DataFrames
temp_1 = pd.read_csv(url1)
temp_2 = pd.read_csv(url2)

# %%
# df_temp1

def calculate_adjusted_year(Age):
    if Age <= 0:
        # Years AD (Anno Domini): Positive, counting from year 0
        return int(1950 - Age)
    else:
        # Years BC (Before Christ): Negative, counting down to year 0
        return int(Age - 1950) * -1

temp_1['Year'] = temp_1['Age'].apply(calculate_adjusted_year)    

# Rename columns
temp_1 = temp_1.rename(columns={'Temperature': 'Temp'})

new_column_order = ['Year', 'Temp']
df_temp1 = temp_1.reindex(columns=new_column_order)


# df_temp2

# Convert all temperature columns to numeric, invalid parsing will be set as NaN
for col in temp_2.columns[2:]:
    temp_2[col] = pd.to_numeric(temp_2[col], errors='coerce')

# Baseline period to create anomaly
baseline_years = temp_2[(temp_2['Year'] >= 1961) & (temp_2['Year'] <= 1990)]

columns_to_average = [
    'January_Average_Temperature',
    'February_Average_Temperature',
    'March_Average_Temperature',
    'April_Average_Temperature',
    'May_Average_Temperature',
    'June_Average_Temperature',
    'July_Average_Temperature',
    'August_Average_Temperature',
    'September_Average_Temperature',
    'October_Average_Temperature',
    'November_Average_Temperature',
    'December_Average_Temperature'
]

# Convert all temperature columns to numeric, invalid parsing will be set as NaN
for col in temp_2.columns[2:]:
    temp_2[col] = pd.to_numeric(temp_2[col], errors='coerce')

# Calculate the mean temperature for each row in temp_2
temp_2['Temp'] = temp_2[columns_to_average].sum(axis=1) / 12

# Baseline period to create anomaly
baseline_years = temp_2[(temp_2['Year'] >= 1961) & (temp_2['Year'] <= 1990)]
baseline_avg = baseline_years['Temp'].mean()

# Adjust temp_2['Temp'] to be the temperature anomaly
temp_2['Temp'] = temp_2['Temp'] - baseline_avg

# Column order and consistency
new_column_order = ['Year', 'Temp']
df_temp2 = temp_2.groupby('Year', as_index=False)['Temp'].mean()

# %%
# Merge the DataFrames on 'Year'
temp_df = pd.merge(df_temp1, df_temp2, on='Year', how='outer', suffixes=('_1', '_2'))

# %% [markdown]
# <a id='Temperature-Anomaly-Analysis'></a>
# ## Analysis of Temperature Anomaly Data
#
# In this section, we delve into the temperature anomaly data derived from two distinct sources. The first dataset provides a historical perspective, tracing back hundreds of thousands of years, while the second offers insights into recent climate patterns. Merging these datasets allows for a comprehensive analysis of temperature changes over an extensive period.
#
# ### Descriptive Statistics of Combined Temperature Data
#
# The merged temperature dataset encompasses a wide chronological range, providing a unique opportunity to study both long-term and recent climate variations.

# %%
# Compute the average temperature where both values are present, otherwise take the non-NaN value
temp_df['temp_anomaly'] = temp_df[['Temp_1', 'Temp_2']].mean(axis=1, skipna=True)
temp_df['Temp_1'] = temp_df['Temp_1'].round(2)
temp_df['Temp_2'] = temp_df['Temp_2'].round(2)
temp_df['temp_anomaly'] = temp_df['temp_anomaly'].round(2)
temp_df.sort_values(by='Year')
# Out:
#         Year  Temp_1  Temp_2  temp_anomaly
# 5798 -798639   -8.92     NaN         -8.92
# 5797 -797551   -8.88     NaN         -8.88
# 5796 -796493   -8.54     NaN         -8.54
# 5795 -795458   -8.73     NaN         -8.73
# 5794 -794499   -8.53     NaN         -8.53
# ...      ...     ...     ...           ...
# 5918    2015     NaN    0.82          0.82
# 5919    2016     NaN    1.01          1.01
# 5920    2017     NaN    0.91          0.91
# 5921    2018     NaN    0.67          0.67
# 5922    2019     NaN    0.69          0.69
#
# [5923 rows x 4 columns]

# %%
import matplotlib.pyplot as plt

plt.style.use('seaborn-darkgrid')
plt.figure(figsize=(14, 7))
plt.plot(temp_df['Year'], temp_df['temp_anomaly'], marker='o', linestyle='-', linewidth=2, color='steelblue', markersize=5)
plt.title('Temperature Anomaly from the Last 800+ Years', fontsize=18)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Temperature Anomaly (°C)', fontsize=14)

# Add a horizontal line at y=0 to indicate the baseline
plt.axhline(y=0, color='black', linewidth=1, linestyle='--')

plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Visualisation of Temperature Anomaly Over the Last 800k+ Years
#
# The chart above presents the fluctuations in temperature anomalies over the past 800k+ years, offering crucial insights into historical climate patterns and trends.
#
# **Key Observations from the Chart**:
#
# - **Long-Term Trends**: The line plot reveals significant variations in temperature anomalies over the centuries.
#
# - **Modern Era Variability**: The latter part of the chart, representing more recent years, shows a noticeable change in the frequency and magnitude of temperature anomalies. This shift aligns with the period of accelerated industrialization and increased greenhouse gas emissions.
#
# - **Baseline Reference**: The horizontal line at y=0 serves as a baseline, indicating the average temperature from a specified reference period. Deviations above and below this line represent warmer and cooler years, respectively, compared to the baseline.
#
# - **Contextual Interpretation**: This visualization underscores the heightened variability and trend towards increasing temperature anomalies in recent decades, aligning with the broader narrative of global climate change.
#
# The data portrayed in this chart is instrumental in understanding the progression and impact of climate change, serving as a visual representation of how our planet's climate has shifted over time and continues to evolve.

# %%
# Now we combine the datasets and do an overlapping chart
combined_df = pd.merge(co2_df, temp_df, on='Year', how='outer', suffixes=('_co2', '_temp'))

# Comparing both visualss

import matplotlib.pyplot as plt

plt.style.use('seaborn-darkgrid')
fig, ax1 = plt.subplots(figsize=(14, 7))
color = 'seagreen'
ax1.set_xlabel('Year', fontsize=14)
ax1.set_ylabel('CO2 Concentration (ppmv)', fontsize=14, color=color)
ax1.plot(co2_df['Year'], co2_df['Co2'], color=color, marker='o', linestyle='-', linewidth=2, label='CO2 Concentration')
ax1.tick_params(axis='y', labelcolor=color)
ax1.grid(False)

# twin y-axis to share the same x-axis for teperature anomaly
ax2 = ax1.twinx()
color = 'steelblue'
ax2.set_ylabel('Temperature Anomaly (°C)', fontsize=14, color=color)
ax2.plot(temp_df['Year'], temp_df['temp_anomaly'], color=color, marker='o', linestyle='-', linewidth=2, label='Temperature Anomaly')
ax2.tick_params(axis='y', labelcolor=color)

plt.title('CO2 Concentration and Temperature Anomaly Over Years', fontsize=18)
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

fig.tight_layout()
plt.show()

# %%
# Generate descriptive statistics
desc4_stats = combined_df.describe()

# Display the descriptive statistics
print(desc4_stats)
# Out:
#                 Year          Co2      co2_dev       Temp_1      Temp_2  \
# count    7702.000000  1923.000000  1923.000000  5789.000000  193.000000
# mean  -200576.689172   237.421622     0.001622    -4.575217   -0.101865
# std    216743.711022    39.656785    39.656785     3.448436    0.347965
# min   -803718.000000   173.710000   -63.710000   -10.580000   -0.640000
# 25%   -307866.750000   205.145000   -32.275000    -7.450000   -0.340000
# 50%   -116157.000000   233.000000    -4.420000    -5.200000   -0.170000
# 75%    -30823.250000   259.550000    22.130000    -1.810000    0.010000
# max      2023.000000   421.080000   183.660000     5.460000    1.010000
#
#        temp_anomaly
# count   5977.000000
# mean      -4.434967
# std        3.482088
# min      -10.580000
# 25%       -7.390000
# 50%       -5.050000
# 75%       -1.420000
# max        5.460000

# %% [markdown]
# ### Comparative Visualization of CO2 Concentration and Temperature Anomaly
#
# This combined chart offers a visual comparison between atmospheric CO2 concentration and temperature anomalies over the years, highlighting their correlation and potential interdependencies.
#
# **Observations from the Combined Chart**:
#
# - **Correlated Trends**: The overlay of CO2 concentration (green) and temperature anomaly (blue) on the same timeline allows us to observe the correlation between these two critical climate indicators. Notably, the increase in CO2 levels appears to align closely with the rise in temperature anomalies, especially in recent decades.
#
# - **Dual Axes Representation**: The use of dual y-axes enables an effective comparison of two different measurement scales, providing a clear view of how each variable has evolved over time.
#
# - **Historical Context and Modern Impact**: The chart traces the historical patterns of both CO2 and temperature anomalies, with a marked change in the trend observed during the period of industrialization, emphasizing the impact of human activities on climate change.
#
# ---

# %% [markdown]
# <a id='Methane-Analysis'></a>
# ## Additional Analyses: Methane (CH4)
#
# Following the analysis of CO2 and temperature anomalies, we now shift our focus to Methane (CH4), another crucial greenhouse gas. Methane has a significant impact on climate change, being more effective than CO2 at trapping heat in the atmosphere, albeit with a shorter atmospheric lifetime.
#
# ### Data Sources and Processing
#
# We sourced CH4 data from multiple repositories, including historical and modern records. These datasets provide a comprehensive view of CH4 concentrations over a wide temporal range:
#
# - Historical data spanning several hundred thousand years.
# - Recent observations from various global monitoring stations.
#
# The datasets were processed as follows:
#
# 1. **Data Import**: CH4 data was imported from four different URLs hosted on GitHub, each contributing a unique set of observations.
#
# 2. **Year Adjustment**: For datasets with gas age data, a function `calculate_adjusted_year` was used to convert gas ages into standard year format (AD/BC).
#
# 3. **Data Cleaning and Transformation**: The CH4 concentrations from each dataset were renamed for consistency and converted to numeric values, handling any non-numeric entries as NaN.
#
# 4. **Combining Datasets**: The datasets were combined to form a single, comprehensive view of CH4 concentrations. This involved grouping the data by year and calculating the mean CH4 concentration for each year.
#
# 5. **Creating a Master CH4 Column**: An average CH4 value (`CH4_master`) was calculated for each year across all datasets, providing a unified measure of CH4 concentration.
#
# The resulting combined dataset offers a detailed view of CH4 variations and trends over an extensive period, aiding in understanding its role in climate dynamics.
#
# **Data Source Acknowledgment**:
#
# Our analysis relies on data compiled from various reputable sources, ensuring the robustness and reliability of our findings. These sources include long-term ice core data and recent measurements from monitoring stations, each contributing valuable insights into CH4's historical and contemporary levels.

# %%
import pandas as pd

# Updated URLs of the datasets
github_url1 = "https://raw.githubusercontent.com/nf-me/project2/master/data_files/ch4_data/edc-ch4-2008.csv"
github_url2 = "https://raw.githubusercontent.com/nf-me/project2/ba639b81d4e4b03e9c418b9a81021996b357c4c5/data_files/ch4_data/ch4_annmean_gl.csv"
github_url3 = "https://raw.githubusercontent.com/nf-me/project2/ba639b81d4e4b03e9c418b9a81021996b357c4c5/data_files/ch4_data/ch4_mm_gl.csv"
github_url4 = "https://raw.githubusercontent.com/nf-me/project2/ba639b81d4e4b03e9c418b9a81021996b357c4c5/data_files/ch4_data/law_ch4.csv"

# Read datasets
df1 = pd.read_csv(github_url1)
df2 = pd.read_csv(github_url2)
df3 = pd.read_csv(github_url3)
df4 = pd.read_csv(github_url4)

# Combine datasets
#combined_df = pd.concat([df1, df2, df3, df4], ignore_index=True)

# Save combined data to CSV
#combined_df.to_csv('combined_methane_data.csv', index=False)

# Adjusting year in df1
def calculate_adjusted_year(gas_age):
    return 1950 - gas_age if gas_age <= 0 else (gas_age - 1950) * -1

df1['Year'] = df1['Gas Age'].apply(calculate_adjusted_year)

# Adjusting year in df4
def calculate_adjusted_year(gas_age):
    return 1950 - gas_age if gas_age <= 0 else (gas_age - 1950) * -1

df1['Year'] = df1['Gas Age'].apply(calculate_adjusted_year)


# Extract required columns
df1 = df1.rename(columns={'CH4 mean': 'CH4_1'})
df1 = df1[['Year', 'CH4_1']]

df2 = df2.rename(columns={'year': 'Year'})
df2 = df2.rename(columns={'mean': 'CH4_2'})
df2 = df2[['Year', 'CH4_2']] 

df3 = df3.rename(columns={'year': 'Year'})
df3 = df3.rename(columns={'average': 'CH4_3'})
df3 = df3[['Year', 'CH4_3']]  

df4 = df4.rename(columns={'air age (AD)': 'Year'})
df4 = df4.rename(columns={'CH4 (ppb)': 'CH4_4'})
df4 = df4[['Year', 'CH4_4']]

# Convert 'CH4' columns to numeric and handle errors by setting invalid parsing as NaN
df1['CH4_1'] = pd.to_numeric(df1['CH4_1'], errors='coerce')
df2['CH4_2'] = pd.to_numeric(df2['CH4_2'], errors='coerce')
df3['CH4_3'] = pd.to_numeric(df3['CH4_3'], errors='coerce')
df4['CH4_4'] = pd.to_numeric(df4['CH4_4'], errors='coerce')

# Group by 'Year' and calculate mean
df1_grouped = df1.groupby('Year')['CH4_1'].mean().to_frame(name='CH4_df1')
df2_grouped = df2.groupby('Year')['CH4_2'].mean().to_frame(name='CH4_df2')
df3_grouped = df3.groupby('Year')['CH4_3'].mean().to_frame(name='CH4_df3')
df4_grouped = df4.groupby('Year')['CH4_4'].mean().to_frame(name='CH4_df4')

# Combine grouped dataframes
combined_df = pd.concat([df1_grouped, df2_grouped, df3_grouped, df4_grouped], axis=1)

# Calculate the average CH4 value for each year, ignoring NaN values
combined_df['CH4_master'] = combined_df.mean(axis=1)

combined_df['CH4_master'] = combined_df['CH4_master'].round(2)

# Reset index to make 'Year' a column again
combined_df.reset_index(inplace=True)

# Display the first few rows of the combined dataframe
combined_df.head()
# Out:
#      Year  CH4_df1  CH4_df2  CH4_df3  CH4_df4  CH4_master
# 0 -797446    399.0      NaN      NaN      NaN       399.0
# 1 -796467    458.0      NaN      NaN      NaN       458.0
# 2 -795327    396.0      NaN      NaN      NaN       396.0
# 3 -794370    418.0      NaN      NaN      NaN       418.0
# 4 -792988    428.0      NaN      NaN      NaN       428.0

# %% [markdown]
# ### Overview of Methane (CH4) Concentration Data
#
# The table above presents the initial part of our comprehensive CH4 dataset, which covers a substantial temporal range, stretching from 797,446 years BC to the present day. The 'CH4_master' column represents the average CH4 concentration (in parts per billion) for each year, calculated across all datasets.
#
# ### Key Observations from the Descriptive Statistics:
#
# - **Historical CH4 Levels**: The early years in the dataset show significant CH4 concentrations, with values such as 399 ppb, 458 ppb, and so forth, suggesting notable methane presence in the atmosphere even in pre-industrial times.
#
# - **Data Sparsity**: The presence of NaN values in the individual dataset columns (CH4_df1 to CH4_df4) for certain years indicates gaps in the data, which is not uncommon in long-range historical datasets.
#
# - **Consolidation into CH4_master**: The calculated 'CH4_master' values provide a consolidated view of methane concentrations, offering a more continuous and comprehensive perspective of methane levels over the millennia.

# %%
import matplotlib.pyplot as plt

year = combined_df['Year']
ch4_master = combined_df['CH4_master']

plt.style.use('seaborn-darkgrid')
plt.figure(figsize=(14, 7))

# Plotting CH4 data
plt.plot(year, ch4_master, marker='o', linestyle='-', linewidth=2, color='orange', markersize=5)
plt.title('CH4 Concentration over Years', fontsize=18)
plt.xlabel('Year', fontsize=14)
plt.ylabel('CH4 Concentration', fontsize=14)  # Update the ylabel accordingly

plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Methane Concentration Visualization
#
# The line plot below visualizes the CH4 concentration over the years, providing a visual representation of the methane trends identified in the descriptive statistics:
#
# **Observations from the CH4 Concentration Chart**:
#
# - **Visual Trend**: The plot, marked by an orange line, exhibits the fluctuations and general trends in methane concentration over time. It allows for easy observation of both long-term patterns and shorter-term variations.
#
# - **Contextual Interpretation**: This visualization is particularly useful in understanding the variations in CH4 levels in relation to historical climate events and human activities, especially in the context of industrialization and its impact on greenhouse gas emissions.
#
# Overall, the combination of descriptive statistics and visual analysis offers valuable insights into CH4 concentration trends, contributing to our understanding of its role in historical and contemporary climate dynamics.
#
# ---

# %% [markdown]
# <a id='Combined-Analysis'></a>
# ## Bringing Together CO2, Temperature Anomaly, and CH4 Data
#
# After individually analysing CO2, temperature anomaly, and CH4 data, we now bring these crucial climate indicators together. This holistic approach allows us to examine the interplay between these variables and gain a deeper understanding of their collective impact on climate change.

# %%
import matplotlib.pyplot as plt

plt.style.use('seaborn-darkgrid')
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(14, 14), sharex=True)

# CO2 Plot
color = 'seagreen'
ax1.set_ylabel('CO2 Concentration (ppmv)', fontsize=14, color=color)
ax1.plot(co2_df['Year'], co2_df['Co2'], color=color, marker='o', linestyle='-', linewidth=2, label='CO2 Concentration')
ax1.tick_params(axis='y', labelcolor=color)
ax1.legend(loc='upper left')
ax1.grid(True, which='both', linestyle='--', linewidth=0.5)

# Temperature Anomaly Plot
color = 'steelblue'
ax2.set_ylabel('Temperature Anomaly (°C)', fontsize=14, color=color)
ax2.plot(temp_df['Year'], temp_df['temp_anomaly'], color=color, marker='o', linestyle='-', linewidth=2, label='Temperature Anomaly')
ax2.tick_params(axis='y', labelcolor=color)
ax2.legend(loc='upper left')
ax2.grid(True, which='both', linestyle='--', linewidth=0.5)

# CH4 Plot
color = 'orange'
ax3.set_xlabel('Year', fontsize=14)
ax3.set_ylabel('CH4 Concentration', fontsize=14, color=color)
ax3.plot(combined_df['Year'], combined_df['CH4_master'], color=color, marker='o', linestyle='-', linewidth=2, label='CH4 Concentration')
ax3.tick_params(axis='y', labelcolor=color)
ax3.legend(loc='upper left')
ax3.grid(True, which='both', linestyle='--', linewidth=0.5)

plt.suptitle('CO2 Concentration, Temperature Anomaly, and CH4 Concentration Over Years', fontsize=18)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
import matplotlib.pyplot as plt

# Cahrt is quite messy but the below shows the correclation from a visual persepctive nciely. 
# Again if I were to redo this chart I would attempt to do something more visual

plt.style.use('seaborn-darkgrid')
fig, ax1 = plt.subplots(figsize=(14, 7))

# CO2 Plot
color = 'seagreen'
ax1.set_xlabel('Year', fontsize=14)
ax1.set_ylabel('CO2 Concentration (ppmv)', fontsize=14, color=color)
ax1.plot(co2_df['Year'], co2_df['Co2'], color=color, marker='o', linestyle='-', linewidth=2, label='CO2 Concentration')
ax1.tick_params(axis='y', labelcolor=color)
ax1.grid(False)

# Temperature Anomaly Plot
ax2 = ax1.twinx()
color = 'steelblue'
ax2.set_ylabel('Temperature Anomaly (°C)', fontsize=14, color=color)
ax2.plot(temp_df['Year'], temp_df['temp_anomaly'], color=color, marker='o', linestyle='-', linewidth=2, label='Temperature Anomaly')
ax2.tick_params(axis='y', labelcolor=color)

# CH4 Plot
ax3 = ax1.twinx()
color = 'orange'
ax3.spines['right'].set_position(('outward', 60))  # Offset the right spine of ax3
ax3.set_ylabel('CH4 Concentration', fontsize=14, color=color)
ax3.plot(combined_df['Year'], combined_df['CH4_master'], color=color, marker='o', linestyle='-', linewidth=2, label='CH4 Concentration')
ax3.tick_params(axis='y', labelcolor=color)

plt.title('CO2 Concentration, Temperature Anomaly, and CH4 Concentration Over Years', fontsize=18)
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')
ax3.legend(loc='center right')

fig.tight_layout()
plt.show()

# %%
# Merge combined_df (CH4) with co2_df
ch4co2_df = pd.merge(combined_df[['Year', 'CH4_master']], co2_df, on='Year', how='outer')

# Rename 'CH4_master' to 'CH4'
ch4co2_df.rename(columns={'CH4_master': 'CH4'}, inplace=True)

# Merge the resulting DataFrame with temp_df
all_variables_df = pd.merge(ch4co2_df, temp_df[['Year', 'temp_anomaly']], on='Year', how='outer')

# Display the first few rows of the final combined dataframe
all_variables_df.sort_values(by='Year')
# Out:
#         Year      CH4     Co2  co2_dev  temp_anomaly
# 2241 -803718      NaN  207.29   -30.13           NaN
# 2242 -803182      NaN  202.23   -35.19           NaN
# 2243 -802572      NaN  204.86   -32.56           NaN
# 2244 -802059      NaN  207.50   -29.92           NaN
# 2245 -801975      NaN  202.92   -34.50           NaN
# ...      ...      ...     ...      ...           ...
# 2142    2019  1866.62  411.65   174.23          0.69
# 2143    2020  1879.01  414.21   176.79           NaN
# 2144    2021  1895.35  416.41   178.99           NaN
# 2145    2022  1911.89  418.53   181.11           NaN
# 2148    2023  1919.96  421.08   183.66           NaN
#
# [9771 rows x 5 columns]

# %% [markdown]
# ### Comprehensive Analysis of Combined Climate Data
#
# The integration of CO2 levels, temperature anomalies, and methane concentrations into a single analysis framework provides us with a multi-faceted view of climate dynamics. This combined analysis reveals several key insights:
#
# - **Correlated Trends**: There's a noticeable correlation between the rise in CO2 and CH4 levels and the increase in temperature anomalies, especially in the context of the industrial era. This correlation underscores the significant role of greenhouse gases in driving global warming.
#
# - **Historical Context**: By examining data that stretches back hundreds of thousands of years, we gain perspective on the natural variations in these climate indicators and can better assess the extent of human impact in recent times.
#
# - **Contemporary Climate Signals**: Recent data trends show an accelerated increase in greenhouse gas concentrations alongside rising temperature anomalies, aligning with the broader narrative of rapid climate change in the modern era.
#
# - **Implications for Climate Policy**: This analysis provides empirical evidence supporting the need for robust climate policies aimed at reducing greenhouse gas emissions. It also highlights the importance of continued monitoring and research to inform adaptive strategies in response to climate change.
#
# In summary, the collective examination of CO2, temperature anomaly, and CH4 datasets not only reinforces the link between human activities and climate change of which to exoplore and comment on would be outside the scope of this project.
#
# ---

# %% [markdown]
# <a id='Irish-Context'></a>
# ## The Irish Context

# %%
# I did not get an opportunity to do a full analysis and work within this section

# data in folder on GitHub, ran out of time and will revisit post assignment

# %% [markdown]
# ---

# %% [markdown]
# <a id='Data-Fusion-and-Analysis'></a>
# ## Data Fusion and Analysis
#
# In the Data Fusion and Analysis phase, we integrate the key climate variables—CH4, CO2, and temperature anomalies. This integrated approach allows us to explore the interrelationships among these crucial climate indicators more effectively.

# %%
# Creating a Correlation Matrix
columns_to_include = ['CH4', 'Co2', 'temp_anomaly']
correlation_matrix = all_variables_df[columns_to_include].corr()

# Plotting the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ### Insights from the Correlation Matrix
#
# - **Heatmap Visualization**: The heatmap provides an intuitive visual representation of the correlation matrix, with color intensity reflecting the strength of the relationship between each pair of variables.
# - **Correlation Values**: The annotated values on the heatmap indicate the correlation coefficients, suggesting the degree of linear relationship between the variables.
# - **Interpretation**: The correlation coefficients can infer potential relationships, such as a strong positive correlation between CO2 and temperature anomalies indicating a rise in temperature as CO2 levels increase.

# %% [markdown]
# ### Time Series Decomposition of Temperature Anomaly

# %%
# Cross-Correlation Analysis

# Decomposing temperature anomaly data
decompose_result = seasonal_decompose(all_variables_df['temp_anomaly'].dropna(), model='additive', period=12)
decompose_result.plot()
plt.show()

# %% [markdown]
# ### Autocorrelation and Partial Autocorrelation Analysis for CH4

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# Autocorrelation for CH4
plt.figure(figsize=(12, 5))
plot_acf(all_variables_df['CH4'].dropna(), ax=plt.gca(), lags=30)
plt.title('Autocorrelation for CH4')
plt.show()

# Partial Autocorrelation for CH4
plt.figure(figsize=(12, 5))
plot_pacf(all_variables_df['CH4'].dropna(), ax=plt.gca(), lags=30, method='ywm')
plt.title('Partial Autocorrelation for CH4')
plt.show()

# %% [markdown]
# #### Observations from the ACF Plot for CH4
#
# - **Lag Relationship**: The ACF plot shows how CH4 levels are correlated with their previous values at different lags.
# - **Correlation Strength**: The height and direction of the bars indicate the strength and nature (positive or negative) of the correlation.
# - **Seasonality Indication**: Regular patterns or repeating spikes can suggest seasonality in the CH4 data.
# - **Randomness Indicator**: Small autocorrelations (within the blue shaded area) might imply randomness in the data, suggesting a lack of predictable structure.
#
# #### Observations from the PACF Plot for CH4
#
# - **Direct Lag Relationship**: The PACF plot indicates the direct correlation of CH4 with its lags, accounting for the values of intermediate lags.
# - **Significant Lags**: Spikes beyond the blue shaded area suggest statistically significant correlations at specific lags.
# - **Model Identification**: The pattern and cutoff in the PACF can help in identifying the order of the autoregressive part of time series models.

# %% [markdown]
# ### Frequency Analysis of CO2 Data

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal

# I believe I have not actioned the below correct so will not offer analysis due to time restraints. 
# I will finsish this post assingment in github

# Normalise
co2_normalized = (all_variables_df['Co2'].dropna() - all_variables_df['Co2'].dropna().mean()) / all_variables_df['Co2'].dropna().std()

# Detrend the normalised data
co2_detrended = signal.detrend(co2_normalized)

# Applying Fourier Transform on the detrended data
fft_co2 = np.fft.fft(co2_detrended)
frequencies_co2 = np.fft.fftfreq(len(fft_co2))

# Plotting the frequency spectrum (using logarithmic scale for amplitude)
plt.figure(figsize=(12, 6))
plt.plot(frequencies_co2[start_freq:end_freq], np.log(np.abs(fft_co2[start_freq:end_freq])))
plt.title('Frequency Spectrum of Detrended CO2 (Log Scale)')
plt.xlabel('Frequency')
plt.ylabel('Log Amplitude')
plt.show()

# %% [markdown]
# ### Frequency Analysis of CO2 Data Interpretation
#
# ---

# %% [markdown]
# <a id='Future-Predictions'></a>
# ## 5. Future Predictions and Comparisons
#
# In this section, we turn our attention to forecasting future global temperature anomalies, using the insights gleaned from our historical climate data analysis. Our objective is to project temperature trends for the coming decades, considering the continuation of current atmospheric CO2 trends. To ground our predictions in context, we will compare our synthesized forecasts with existing published climate models. This comparison aims to validate our projections and understand how our findings align with established climate research.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# very bad future model as I ran out of time. Will revisit post assingment and update github
clean_data = all_variables_df.dropna(subset=['Co2', 'temp_anomaly'])

# Linear Regression Model
model = LinearRegression()
model.fit(clean_data[['Co2']], clean_data['temp_anomaly'])

# Predicting future temperature anomalies based on CO2 trends
# next 50 years
future_co2 = np.arange(clean_data['Co2'].max(), clean_data['Co2'].max() + 50)
predicted_temp_anomalies = model.predict(future_co2.reshape(-1, 1))

# results
plt.figure(figsize=(12, 6))
plt.scatter(clean_data['Co2'], clean_data['temp_anomaly'], color='blue', label='Historical Data')
plt.plot(future_co2, predicted_temp_anomalies, color='red', label='Predicted Temp Anomalies')
plt.title('Predicted Global Temperature Anomalies')
plt.xlabel('CO2 Concentration')
plt.ylabel('Temperature Anomaly (°C)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\neilf\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ### Summary and Conclusions from the Predictive Analysis
#
# - **Key Findings**: The linear projection indicates a continued increase in global temperature anomalies in line with rising CO2 levels.
# - **Consistency with Climate Science**: Our findings are consistent with the broad scientific consensus on the impact of greenhouse gases on global warming.
# - **Limitations**: The linear model is a simplification and doesn't capture the complexities of climate dynamics.
# - **Next Steps**: For a comprehensive analysis, advanced forecasting methods and a comparison with detailed climate models from sources like IPCC are recommended.
# - **Further Research**: Comparing our model's predictions with established climate models will provide a more nuanced understanding of future
#
# ---

# %% [markdown]
# ### Commentary on Accelerated Warming: Latest Features and Indicators
#
# #### Observations on Recent Temperature Trends:
#
# The latest climate data exhibits a clear trend of accelerated global warming. Recent years have repeatedly been recorded among the warmest since modern records began. This rise in global temperatures is indicative of an ongoing trend of accelerated climate change, primarily driven by increased greenhouse gas emissions. The data suggest not only a rise in average temperatures but also an increase in the frequency and intensity of extreme weather events, which can be attributed to this warming trend.
#
# #### Polar Ice-Coverage Decline (althought not specifically covered):
#
# One of the most alarming indicators of accelerated warming is the observed decline in polar ice coverage. Satellite data over recent decades has consistently shown a reduction in the extent and thickness of Arctic sea ice. This decline is consequential as it not only serves as a clear indicator of rising global temperatures but also contributes to a feedback loop that exacerbates warming: as ice melts, less sunlight is reflected away from Earth's surface, leading to further warming and more ice loss.
#
# #### Implications and Future Outlook:
#
# The accelerated warming, evidenced by increasing global temperatures and decreasing polar ice coverage, is a clarion call for urgent action in climate policy and research. It underscores the need for immediate and substantial reductions in greenhouse gas emissions to mitigate the most severe impacts of climate change. Furthermore, it highlights the importance of continued monitoring and research into the Earth's climate system to better predict and prepare for future changes.

# %% [markdown]
# <a id='Concluding-Remarks'></a>
# ## Concluding Remarks and Acknowledgements
#
# ### Reflection on Sources and Referencing
#
# Throughout this analysis, due to time constraints, detailed referencing of all the sources and datasets used has not been possible due to time restrainits on my part. However, it's important to note that our study is grounded in data and insights from a variety of reputable sources in the field of climate science. These include, but are not limited to:
#
# - Intergovernmental Panel on Climate Change (IPCC)
# - National Oceanic and Atmospheric Administration (NOAA)
# - NASA's Goddard Institute for Space Studies
# - World Meteorological Organization (WMO)
# - Online help forums
#
# Each of these sources has been instrumental in shaping our understanding of climate dynamics and in providing the data necessary for our analysis.
#
# ### Future Directions
#
# In future iterations of this work, a more comprehensive approach to referencing and sourcing will be adopted, ensuring that each dataset, model, and analytical method is appropriately credited. This not only strengthens the credibility of the analysis but also provides clear pathways for those interested in further research to follow and verify our work.

# %% [markdown]
# ### Export Data to CSV and JSON

# %%
# Exporting the DataFrame to a CSV file
all_variables_df.to_csv('fused_climate_data.csv', index=False)

# Exporting the DataFrame to a JSON file
all_variables_df.to_json('fused_climate_data.json', orient='records')
